# %%
j_dict = {'BAH': 'Bahamas',
 'BERMU': 'Bermuda',
 'BRUN': 'Brunei',
 'BVI': 'British Virgin Islands',
 'CAYMN': 'Cayman',
 'CHINA': 'China',
 'COOK': 'Cook Islands',
 'CYP': 'Cyprus',
 'DUBAI': 'Dubai',
 'HK': 'Hong Kong',
 'IRELD': 'Ireland',
 'LABUA': 'Labuan',
 'LIBER': 'Liberia',
 'MALAY': 'Malaysia',
 'MARSH': 'Marshall Islands',
 'MAURI': 'Mauritius',
 'NETH': 'Netherlands',
 'PMA': 'Panama',
 'SAM': 'Samoa',
 'SEY': 'Seychelles',
 'SGP': 'Singapore',
 'STLU': 'St. Lucia',
 'THAIL': 'Thailand',
 'UK': 'United Kingdom',
 'USA': 'United States Of America',
 'VANU': 'Vanuatu',
 'XXX': 'Recorded in leaked files as "fund"'}

# %% [markdown]
# | Jurisdition   | Description                        |
# |:--------------|:-----------------------------------|
# | BVI           | British Virgin Islands             |
# | CAYMN         | Cayman                             |
# | HK            | Hong Kong                          |
# | SAM           | Samoa                              |
# | SEY           | Seychelles                         |
# | XXX           | Recorded in leaked files as "fund" |
# | SGP           | Singapore                          |
# | LABUA         | Labuan                             |
# | MARSH         | Marshall Islands                   |
# | MAURI         | Mauritius                          |
# | PMA           | Panama                             |
# | STLU          | St. Lucia                          |
# | MALAY         | Malaysia                           |
# | DUBAI         | Dubai                              |
# | VANU          | Vanuatu                            |
# | COOK          | Cook Islands                       |
# | BERMU         | Bermuda                            |
# | BRUN          | Brunei                             |
# | LIBER         | Liberia                            |
# | UK            | United Kingdom                     |
# | USA           | United States Of America           |
# | BAH           | Bahamas                            |
# | CYP           | Cyprus                             |
# | CHINA         | China                              |
# | THAIL         | Thailand                           |
# | NETH          | Netherlands                        |
# | IRELD         | Ireland                            |

# %% [markdown]
# | nodes                    | Null Percentage   |
# |:-------------------------|:------------------|
# | state                    | 98%               |
# | jurisdiction_description | 81%               |
# | jurisdiction             | 81%               |
# | address                  | 79%               |
# | ibcRUC                   | 66%               |
# | incorporation_date       | 65%               |
# | status                   | 65%               |
# | company_type             | 63%               |
# | service_provider         | 62%               |
# | latitude                 | 37%               |
# | longitude                | 37%               |
# | name                     | 20%               |
# | country_codes            | 18%               |
# | continents               | 18%               |
# | countries                | 18%               |
# | country_count            | 0%                |
# | table                    | 0%                |
# | node_id                  | 0%                |

# %%
country_codes = {'Algeria': 'DZA',
  'Andorra': 'AND',
  'Angola': 'AGO',
  'Anguilla': 'AIA',
  'Antigua and Barbuda': 'ATG',
  'Argentina': 'ARG',
  'Armenia': 'ARM',
  'Australia': 'AUS',
  'Austria': 'AUT',
  'Azerbaijan': 'AZE',
  'Bahamas': 'BHS',
  'Bahrain': 'BHR',
  'Bangladesh': 'BGD',
  'Barbados': 'BRB',
  'Belarus': 'BLR',
  'Belgium': 'BEL',
  'Belize': 'BLZ',
  'Benin': 'BEN',
  'Bermuda': 'BMU',
  'Bhutan': 'BTN',
  'Bosnia and Herzegovina': 'BIH',
  'Botswana': 'BWA',
  'Brazil': 'BRA',
  'British Virgin Islands': 'VGB',
  'Brunei': 'BRN',
  'Bulgaria': 'BGR',
  'Cambodia': 'KHM',
  'Canada': 'CAN',
  'Cayman Islands': 'CYM',
  'Chile': 'CHL',
  'China': 'CHN',
  'Colombia': 'COL',
  'Cook Islands': 'COK',
  'Costa Rica': 'CRI',
  'Croatia': 'HRV',
  'Curaçao': 'CUW',
  'Cyprus': 'CYP',
  'Czech Republic': 'CZE',
  "Côte d'Ivoire": 'CIV',
  'DR Congo': 'COD',
  'Denmark': 'DNK',
  'Djibouti': 'DJI',
  'Dominica': 'DMA',
  'Dominican Republic': 'DOM',
  'Ecuador': 'ECU',
  'Egypt': 'EGY',
  'El Salvador': 'SLV',
  'Estonia': 'EST',
  'Fiji': 'FJI',
  'Finland': 'FIN',
  'France': 'FRA',
  'French Polynesia': 'PYF',
  'Gabon': 'GAB',
  'Georgia': 'GEO',
  'Germany': 'DEU',
  'Ghana': 'GHA',
  'Gibraltar': 'GIB',
  'Greece': 'GRC',
  'Grenada': 'GRD',
  'Guam': 'GUM',
  'Guernsey': 'GGY',
  'Guinea': 'GIN',
  'Guyana': 'GUY',
  'Hong Kong': 'HKG',
  'Hungary': 'HUN',
  'Iceland': 'ISL',
  'India': 'IND',
  'Indonesia': 'IDN',
  'Iran': 'IRN',
  'Ireland': 'IRL',
  'Isle of Man': 'IMN',
  'Israel': 'ISR',
  'Italy': 'ITA',
  'Jamaica': 'JAM',
  'Japan': 'JPN',
  'Jersey': 'JEY',
  'Jordan': 'JOR',
  'Kazakhstan': 'KAZ',
  'Kenya': 'KEN',
  'Kuwait': 'KWT',
  'Kyrgyzstan': 'KGZ',
  'Laos': 'LAO',
  'Latvia': 'LVA',
  'Lebanon': 'LBN',
  'Lesotho': 'LSO',
  'Liberia': 'LBR',
  'Libya': 'LBY',
  'Liechtenstein': 'LIE',
  'Lithuania': 'LTU',
  'Luxembourg': 'LUX',
  'Macao': 'MAC',
  'Macedonia': 'MKD',
  'Madagascar': 'MDG',
  'Malawi': 'MWI',
  'Malaysia': 'MYS',
  'Maldives': 'MDV',
  'Malta': 'MLT',
  'Marshall Islands': 'MHL',
  'Mauritius': 'MUS',
  'Mexico': 'MEX',
  'Moldova': 'MDA',
  'Monaco': 'MCO',
  'Mongolia': 'MNG',
  'Montenegro': 'MNE',
  'Morocco': 'MAR',
  'Myanmar': 'MMR',
  'Namibia': 'NAM',
  'Nauru': 'NRU',
  'Nepal': 'NPL',
  'Netherlands': 'NLD',
  'New Zealand': 'NZL',
  'Niger': 'NER',
  'Nigeria': 'NGA',
  'Niue': 'NIU',
  'Norfolk Island': 'NFK',
  'North Korea': 'PRK',
  'Northern Mariana Islands': 'MNP',
  'Norway': 'NOR',
  'Oman': 'OMN',
  'Pakistan': 'PAK',
  'Palestine': 'PSE',
  'Panama': 'PAN',
  'Papua New Guinea': 'PNG',
  'Paraguay': 'PRY',
  'Peru': 'PER',
  'Philippines': 'PHL',
  'Poland': 'POL',
  'Portugal': 'PRT',
  'Puerto Rico': 'PRI',
  'Qatar': 'QAT',
  'Romania': 'ROU',
  'Russia': 'RUS',
  'Saint Kitts and Nevis': 'KNA',
  'Saint Lucia': 'LCA',
  'Saint Vincent and the Grenadines': 'VCT',
  'Samoa': 'WSM',
  'Saudi Arabia': 'SAU',
  'Serbia': 'SRB',
  'Seychelles': 'SYC',
  'Sierra Leone': 'SLE',
  'Singapore': 'SGP',
  'Slovakia': 'SVK',
  'Slovenia': 'SVN',
  'South Africa': 'ZAF',
  'South Korea': 'KOR',
  'Spain': 'ESP',
  'Sri Lanka': 'LKA',
  'Suriname': 'SUR',
  'Sweden': 'SWE',
  'Switzerland': 'CHE',
  'Syria': 'SYR',
  'Taiwan': 'TWN',
  'Tajikistan': 'TJK',
  'Tanzania': 'TZA',
  'Thailand': 'THA',
  'Tonga': 'TON',
  'Trinidad and Tobago': 'TTO',
  'Turkey': 'TUR',
  'Turkmenistan': 'TKM',
  'Turks and Caicos Islands': 'TCA',
  'U.S. Virgin Islands': 'VIR',
  'Ukraine': 'UKR',
  'United Arab Emirates': 'ARE',
  'United Kingdom': 'GBR',
  'United States': 'USA',
  'Uruguay': 'URY',
  'Uzbekistan': 'UZB',
  'Vanuatu': 'VUT',
  'Venezuela': 'VEN',
  'Viet Nam': 'VNM',
  'Zimbabwe': 'ZWE'}
